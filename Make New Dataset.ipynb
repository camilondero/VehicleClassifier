# %%
import pandas as pd
import numpy as np
import cv2
from tensorflow import keras
from scipy.io import loadmat
from datetime import datetime, date, time

import matplotlib
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.utils import plot_model, to_categorical
from tensorflow.keras.optimizers import Adam
import tensorflow_datasets as tfds

# %matplotlib inline
matplotlib.rcParams['figure.facecolor'] = '#ffffff'

# %%
import os

# %%
dir=""

# %%
db=loadmat(dir+"cars_annos.mat")
pqr=pd.Series(db)

# %%
pqr['annotations'][0][0][-2][0]
# Out:
# array([1], dtype=uint8)

# %%
for i in pqr['annotations'][0]:
    print(pqr['class_names'][0][i[-2][0][0]][0])
# Out:
# Acura RL Sedan 2012
# Acura RL Sedan 2012
# Acura RL Sedan 2012
# Acura RL Sedan 2012
# Acura RL Sedan 2012
# Acura RL Sedan 2012
# Acura RL Sedan 2012
# Acura RL Sedan 2012
# Acura RL Sedan 2012
# Acura RL Sedan 2012
# Acura RL Sedan 2012
# Acura RL Sedan 2012
# Acura RL Sedan 2012
# Acura RL Sedan 2012
# Acura RL Sedan 2012
# Acura RL Sedan 2012
# Acura RL Sedan 2012
# Acura RL Sedan 2012
# Acura RL Sedan 2012
# Acura RL Sedan 2012
# Acura RL Sedan 2012
# Acura RL Sedan 2012
# Acura RL Sedan 2012
# Acura RL Sedan 2012
# Acura RL Sedan 2012
# Acura RL Sedan 2012
# Acura RL Sedan 2012
# Acura RL Sedan 2012
# Acura RL Sedan 2012
# Acura RL Sedan 2012
# Acura RL Sedan 2012
# Acura RL Sedan 2012
# Acura RL Sedan 2012
# Acura RL Sedan 2012
# Acura RL Sedan 2012
# Acura RL Sedan 2012
# Acura RL Sedan 2012
# Acura RL Sedan 2012
# Acura RL Sedan 2012
# Acura RL Sedan 2012
# Acura RL Sedan 2012
# Acura RL Sedan 2012
# Acura RL Sedan 2012
# Acura RL Sedan 2012
# Acura RL Sedan 2012
# ...

# %%
pqr['class_names'][0]
# Out:
# array([array(['AM General Hummer SUV 2000'], dtype='<U26'),
#        array(['Acura RL Sedan 2012'], dtype='<U19'),
#        array(['Acura TL Sedan 2012'], dtype='<U19'),
#        array(['Acura TL Type-S 2008'], dtype='<U20'),
#        array(['Acura TSX Sedan 2012'], dtype='<U20'),
#        array(['Acura Integra Type R 2001'], dtype='<U25'),
#        array(['Acura ZDX Hatchback 2012'], dtype='<U24'),
#        array(['Aston Martin V8 Vantage Convertible 2012'], dtype='<U40'),
#        array(['Aston Martin V8 Vantage Coupe 2012'], dtype='<U34'),
#        array(['Aston Martin Virage Convertible 2012'], dtype='<U36'),
#        array(['Aston Martin Virage Coupe 2012'], dtype='<U30'),
#        array(['Audi RS 4 Convertible 2008'], dtype='<U26'),
#        array(['Audi A5 Coupe 2012'], dtype='<U18'),
#        array(['Audi TTS Coupe 2012'], dtype='<U19'),
#        array(['Audi R8 Coupe 2012'], dtype='<U18'),
#        array(['Audi V8 Sedan 1994'], dtype='<U18'),
# ...

# %%
print(pqr['annotations'][0][0][1][0][0])
print(pqr['annotations'][0][0][2][0][0])
print(pqr['annotations'][0][0][3][0][0])
print(pqr['annotations'][0][0][4][0][0])
# Out:
# 112
# 7
# 853
# 717

# %%
train=0
test=0

for i in pqr['annotations'][0]:
    
    address=dir+i[0][0]
    x1=i[1][0][0]
    y1=i[2][0][0]
    x2=i[3][0][0]
    y2=i[4][0][0]
    img=cv2.imread(address)
    cropped_image = img[y1:y2, x1:x2]
    if i[-1][0][0]==1:
        dir2="car_ims_new/test/"
    else:
        dir2="car_ims_new/train/"
    finaldir=dir2+pqr['class_names'][0][i[-2][0][0]-1][0].replace('/','_')+'/'+i[0][0][len('/car_ims'):] #clase
    print(finaldir)
    cv2.imwrite(finaldir,cropped_image)
# Out:
# car_ims_new/train/AM General Hummer SUV 2000/000001.jpg
# car_ims_new/train/AM General Hummer SUV 2000/000002.jpg
# car_ims_new/train/AM General Hummer SUV 2000/000003.jpg
# car_ims_new/train/AM General Hummer SUV 2000/000004.jpg
# car_ims_new/train/AM General Hummer SUV 2000/000005.jpg
# car_ims_new/train/AM General Hummer SUV 2000/000006.jpg
# car_ims_new/train/AM General Hummer SUV 2000/000007.jpg
# car_ims_new/train/AM General Hummer SUV 2000/000008.jpg
# car_ims_new/train/AM General Hummer SUV 2000/000009.jpg
# car_ims_new/train/AM General Hummer SUV 2000/000010.jpg
# car_ims_new/train/AM General Hummer SUV 2000/000011.jpg
# car_ims_new/train/AM General Hummer SUV 2000/000012.jpg
# car_ims_new/train/AM General Hummer SUV 2000/000013.jpg
# car_ims_new/train/AM General Hummer SUV 2000/000014.jpg
# car_ims_new/train/AM General Hummer SUV 2000/000015.jpg
# car_ims_new/train/AM General Hummer SUV 2000/000016.jpg
# car_ims_new/train/AM General Hummer SUV 2000/000017.jpg
# ...

# %%
dir2="car_ims_new/test/"
for i in pqr['class_names'][0]:
    os.makedirs(dir2+i[0].replace('/','_'), exist_ok=True)

# %%
import shutil

# %%
dir2="car_ims/test/"
dir3="car_ims/train/"
for subdir, dirs, files in os.walk(dir2):
    for direct in dirs:
        i=0
        for file in os.listdir(dir2+direct):
            if i<26:
                shutil.move(dir2+direct+'/'+file, dir3+direct+'/'+file)
                i=i+1
